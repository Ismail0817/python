# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('dataset.csv')

# %%
df
# Out:
#       Rank                           Name Platform    Year         Genre  \
# 0        1                     Wii Sports      Wii  2006.0        Sports
# 1        2              Super Mario Bros.      NES  1985.0      Platform
# 2        3                 Mario Kart Wii      Wii  2008.0        Racing
# 3        4              Wii Sports Resort      Wii  2009.0        Sports
# 4        5       Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ...    ...                            ...      ...     ...           ...
# 9811  9813               Gundam Breaker 3      PSV  2016.0        Action
# 9812  9814       My Farm Around the World       DS  2008.0    Simulation
# 9813  9815  Fat Princess: Fistful of Cake      PSP  2010.0        Action
# 9814  9816                           Zubo       DS  2008.0          Misc
# 9815  9817                   Street Hoops       GC     NaN        Sports
#
#                         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
# Bar Plot - Top 10 Publishers by Global Sales
top_publishers = df.groupby('Publisher')['Global_Sales'].sum().nlargest(10)
plt.figure(figsize=(10, 6))
top_publishers.plot(kind='bar', color='skyblue')
plt.xlabel('Publisher')
plt.ylabel('Global Sales (in millions)')
plt.title('Top 10 Publishers by Global Sales')
plt.xticks(rotation=45)
plt.show()

# %%
# Scatter Plot - Global Sales vs. Year
plt.figure(figsize=(10, 6))
plt.scatter(df['Year'], df['Global_Sales'], alpha=0.5)
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
plt.title('Global Sales vs. Year')
plt.show()

# %%
# Line Plot - Sales by Year
sales_by_year = df.groupby('Year')['Global_Sales'].sum()
plt.figure(figsize=(10, 6))
sales_by_year.plot(kind='line', marker='o', color='purple')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
plt.title('Sales by Year')
plt.grid(True)
plt.show()

# %%
# Pie Chart - Genre Distribution
genre_counts = df['Genre'].value_counts()
plt.figure(figsize=(10, 6))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Genre Distribution')
plt.show()

# %%
# Box Plot - Sales Distribution by Platform
plt.figure(figsize=(10, 6))
sns.boxplot(x='Platform', y='Global_Sales', data=df)
plt.xlabel('Platform')
plt.ylabel('Global Sales (in millions)')
plt.title('Sales Distribution by Platform')
plt.xticks(rotation=45)
plt.show()

# %%
# Violin Plot - Sales Distribution by Genre
plt.figure(figsize=(10, 6))
sns.violinplot(x='Genre', y='Global_Sales', data=df)
plt.xlabel('Genre')
plt.ylabel('Global Sales (in millions)')
plt.title('Sales Distribution by Genre')
plt.xticks(rotation=45)
plt.show()

# %%
# Stacked Bar Plot - Sales by Region for Top 5 Publishers
top_publishers = df.groupby('Publisher')[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum().nlargest(5, 'NA_Sales')
plt.figure(figsize=(10, 6))
top_publishers[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].plot(kind='bar', stacked=True)
plt.xlabel('Publisher')
plt.ylabel('Sales (in millions)')
plt.title('Sales by Region for Top 5 Publishers')
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.show()
